# %% [markdown]
# <a href="https://colab.research.google.com/github/weixin2007/My-first-repository/blob/main/hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("i am the king of the world")
# Out:
# i am the king of the world
