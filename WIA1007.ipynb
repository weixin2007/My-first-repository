# %% [markdown]
# <a href="https://colab.research.google.com/github/weixin2007/My-first-repository/blob/main/WIA1007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np;
array_2x2 = np.array([[1, 2], [3, 4]])
print("1. 2x2 Array:\n", array_2x2)
# Out:
# 1. 2x2 Array:
#  [[1 2]
#  [3 4]]
